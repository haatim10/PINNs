# %% [markdown]
# # PI-fMI-Fractional-PDE Analysis
#
# Visualization and results analysis for Physics-Informed Neural Network solving Fractional PDEs.

# %%
import sys
sys.path.insert(0, '..')

import json
from pathlib import Path

import torch
import numpy as np
import matplotlib.pyplot as plt
import yaml

from src.model import PINN


def create_test_grid(t_range, x_range, N_t, N_x, device):
    x = torch.linspace(x_range[0], x_range[1], N_x, dtype=torch.float64, device=device)
    t = torch.linspace(t_range[0], t_range[1], N_t, dtype=torch.float64, device=device)
    X, T = torch.meshgrid(x, t, indexing='ij')
    return x, t, X, T


def exact_solution_example(X, T, alpha, problem_type='integro_differential'):
    if problem_type == 'integro_differential':
        return (T ** alpha) * torch.cos(np.pi * X)
    return (T ** alpha) * torch.sin(np.pi * X)


def compute_grid_errors(u_pred, u_exact, t_mesh):
    mask = t_mesh > 1e-10
    diff = (u_pred - u_exact)[mask]
    exact = u_exact[mask]

    return {
        'l2_relative': (torch.norm(diff) / torch.norm(exact)).item(),
        'linf': torch.max(torch.abs(diff)).item(),
        'mean_absolute': torch.mean(torch.abs(diff)).item(),
    }


def plot_comparison(X, T, u_pred, u_exact):
    error = torch.abs(u_pred - u_exact)

    fig, axes = plt.subplots(1, 3, figsize=(16, 4))

    im0 = axes[0].pcolormesh(X.cpu().numpy(), T.cpu().numpy(), u_exact.cpu().numpy(), cmap='viridis', shading='auto')
    axes[0].set_title('Exact')
    axes[0].set_xlabel('x')
    axes[0].set_ylabel('t')
    plt.colorbar(im0, ax=axes[0])

    im1 = axes[1].pcolormesh(X.cpu().numpy(), T.cpu().numpy(), u_pred.cpu().numpy(), cmap='viridis', shading='auto')
    axes[1].set_title('Predicted')
    axes[1].set_xlabel('x')
    axes[1].set_ylabel('t')
    plt.colorbar(im1, ax=axes[1])

    im2 = axes[2].pcolormesh(X.cpu().numpy(), T.cpu().numpy(), error.cpu().numpy(), cmap='hot', shading='auto')
    axes[2].set_title('Absolute Error')
    axes[2].set_xlabel('x')
    axes[2].set_ylabel('t')
    plt.colorbar(im2, ax=axes[2])

    plt.tight_layout()


def plot_training_history(history):
    if not history or not history.get('epochs'):
        print('No history to plot')
        return

    fig, axes = plt.subplots(1, 3, figsize=(15, 4))

    if history.get('loss'):
        axes[0].semilogy(history['epochs'], history['loss'], 'b-')
    axes[0].set_title('Loss')
    axes[0].set_xlabel('Epoch')
    axes[0].grid(True, alpha=0.3)

    if history.get('l2'):
        axes[1].semilogy(history['epochs'], history['l2'], 'g-')
    axes[1].set_title('L2 Relative Error')
    axes[1].set_xlabel('Epoch')
    axes[1].grid(True, alpha=0.3)

    if history.get('linf'):
        axes[2].semilogy(history['epochs'], history['linf'], 'r-')
    axes[2].set_title('Linf Error')
    axes[2].set_xlabel('Epoch')
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()


# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## Load Configuration and Model

# %%
# Load config
with open('../configs/integro_differential.yaml', 'r') as f:
    config = yaml.safe_load(f)

# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

problem = config['problem']
network = config['network']

# Problem parameters
alpha = problem['alpha']
T = problem.get('t_max', 1.0)
x_min = problem['x_min']
x_max = problem['x_max']
problem_type = problem.get('type', 'integro_differential')

print(f'Problem type: {problem_type}')
print(f'Problem: alpha={alpha}, T={T}, x in [{x_min}, {x_max}]')

# %%
# Create model
model = PINN(
    input_dim=network['input_dim'],
    output_dim=network['output_dim'],
    hidden_layers=network['hidden_layers'],
    activation=network['activation'],
    device=device,
)

# Load trained weights
checkpoint_candidates = [
    Path('../outputs/checkpoints_integro_diff/final_model.pt'),
    Path('../outputs/checkpoints/final_model.pt'),
]

checkpoint_path = next((p for p in checkpoint_candidates if p.exists()), None)

if checkpoint_path is not None:
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Loaded model from epoch {checkpoint.get('epoch', 'unknown')}")
    print(f"Checkpoint path: {checkpoint_path}")
else:
    checkpoint = {}
    print('No checkpoint found. Train the model first.')

model.eval()

# %% [markdown]
# ## Evaluate on Test Grid

# %%
# Create test grid
N_test = 100
x_grid, t_grid, X_mesh, T_mesh = create_test_grid(
    t_range=(0.0, T),
    x_range=(x_min, x_max),
    N_t=N_test,
    N_x=N_test,
    device=device,
)

# Predict
with torch.no_grad():
    u_pred = model(X_mesh.flatten(), T_mesh.flatten())
    u_pred = u_pred.reshape(N_test, N_test)

# Exact solution
u_exact = exact_solution_example(X_mesh, T_mesh, alpha, problem_type)

print(f'Prediction shape: {u_pred.shape}')

# %% [markdown]
# ## Error Analysis

# %%
# Compute errors
errors = compute_grid_errors(u_pred, u_exact, T_mesh)

print('Error Metrics:')
for name, value in errors.items():
    print(f'  {name}: {value:.6e}')

# %% [markdown]
# ## Visualization

# %%
# Plot comparison
plot_comparison(X_mesh, T_mesh, u_pred, u_exact)

# %%
# Plot training history
history = None

if checkpoint.get('history'):
    history = checkpoint['history']
elif checkpoint.get('loss_history') and checkpoint.get('error_history'):
    history = {
        'epochs': checkpoint.get('eval_epochs', []),
        'loss': checkpoint['loss_history'].get('total', []),
        'l2': checkpoint['error_history'].get('l2', []),
        'linf': checkpoint['error_history'].get('linf', []),
    }

if history:
    plot_training_history(history)
else:
    history_path = Path('../outputs/logs/training_history.json')
    if history_path.exists():
        with open(history_path, 'r') as f:
            history = json.load(f)
        plot_training_history(history)
    else:
        print('No training history found.')

# %% [markdown]
# ## Solution at Different Time Snapshots

# %%
# Plot solution at different times
times = [0.0, 0.25, 0.5, 0.75, 1.0]
x_plot = torch.linspace(x_min, x_max, 100, dtype=torch.float64, device=device)

fig, ax = plt.subplots(figsize=(10, 6))

for t_val in times:
    t_tensor = torch.full_like(x_plot, t_val)
    with torch.no_grad():
        u_t = model(x_plot, t_tensor)
    ax.plot(x_plot.cpu(), u_t.cpu(), label=f't={t_val}')

ax.set_xlabel('x')
ax.set_ylabel('u(x, t)')
ax.set_title('PINN Solution at Different Times')
ax.legend()
plt.show()
